# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hellow World!")
# Out:
# Hellow World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
user_input = input("Enter your text here: ")
print(user_input)
# Out:
# HELLO

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
user_input = float(input("Enter your number here: "))
if user_input == 0:
    print("number is zero")
elif user_input > 0:
    print('number is positive')
else:
    print('number is negative')
# Out:
# number is negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = float(input("Enter your number 1 here: "))
num2 = float(input("Enter your number 2 here: "))
num3 = float(input("Enter your number 3 here: "))

if((num1>num2) and (num1>num3)):
    largest = num1
elif((num2>num1) and (num2>num3)):
    largest = num2
else:
    largest = num3

print(f"the largest number is {largest}")
# Out:
# the largest number is 30.0

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num = int(input("Enter your number here: "))

fact = 1
for i in range(1,num+1):
    fact = fact*i

print(fact)
# Out:
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
integer_var = 7
float_var = 10.5
string_var = "Hello Wprld"
boolean_var = True

print(f"Integer value: {integer_var}, type: {type(integer_var)}")
print(f"Float value: {float_var}, type: {type(float_var)}")
print(f"String value: {string_var}, type: {type(string_var)}")
print(f"Boolean value: {boolean_var}, type: {type(boolean_var)}")
# Out:
# Integer value: 7, type: <class 'int'>
# Float value: 10.5, type: <class 'float'>
# String value: Hello Wprld, type: <class 'str'>
# Boolean value: True, type: <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a=3
b="hello world"
a,b=b,a
print(a)
print(b)
# Out:
# hello world
# 3

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius = float(input('Enter the degree in Celsius'))
fahrenheit = ((celsius*9)/5)+32
print(fahrenheit)
# Out:
# 80.6

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "hello"
str2 = 'world'
str3 = str1 + ' ' + str2
print(str3)
# Out:
# hello world

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var = 10.5
if isinstance(var, float):
    print(f"{var} is a float")
else:
    print(f"{var} is not a float")
# Out:
# 10.5 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 5
b = 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
# Out:
# Addition: 5 + 3 = 8
# Subtraction: 5 - 3 = 2
# Multiplication: 5 * 3 = 15
# Division: 5 / 3 = 1.6666666666666667

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 5
b = 3

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
# Out:
# 5 == 3: False
# 5 != 3: True
# 5 > 3: True
# 5 < 3: False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False

print(f"True and False: {a and b}")
print(f"True or False: {a or b}")
print(f"not True: {not a}")
# Out:
# True and False: False
# True or False: True
# not True: False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = float(input("Enter a number: "))
square = num ** 2
print(f"The square of {num} is {square}")
# Out:
# The square of 12.0 is 144.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(f"{num} is even.")
else:
    print(f"{num} is odd.")
# Out:
# 2129871 is odd.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n = int(input("Enter a number: "))
sum_n = (n * (n + 1)) // 2
print(f"The sum of the first {n} natural numbers is {sum_n}")
# Out:
# The sum of the first 27 natural numbers is 378

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 21089 is not a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str = "Fast, concise, and the most Pythonic way."
reverse_str = str[::-1]
print(reverse_str)
# Out:
# .yaw cinohtyP tsom eht dna ,esicnoc ,tsaF

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str1 = "radar"
str2 = "radar"

if(str1 == str2[::-1]):
    print('string is palindrome')
else:
    print('string is not a palindrome')
# Out:
# string is palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers = [34, 12, 5, 67, 89, 1, 23]
numbers.sort()
print(numbers)
# Out:
# [1, 5, 12, 23, 34, 67, 89]
